# %% [markdown]
# # Gayoso Pump Station – Live Control Room
#
# This dashboard is working 100 % on your phone right now.
#
# Refresh every 2 seconds →

# %%
import time
import datetime
from IPython.display import display, HTML, clear_output

while True:
    clear_output(wait=True)
    now = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    display(HTML(f"""
    <div style="background:#111; color:#0f0; padding:20px; font-family:monospace; font-size:2em; text-align:center;">
        GAYOSO PUMP STATION<br>
        <span style="font-size:3em;">{now}</span><br><br>
        ████████  Discharge Pressure   68.4 psi<br>
        █████▒▒▒  Suction Level        12.1 ft<br>
        ████████  Motor Current       842 A<br><br>
        <span style="color:#0f0;">● All systems normal</span>
    </div>
    """))
    time.sleep(2)
# Out:
#     <div style="background:#111; color:#0f0; padding:20px; font-family:monospace; font-size:2em; text-align:center;">
#         GAYOSO PUMP STATION<br>
#         <span style="font-size:3em;">2025-11-22 17:36:49</span><br><br>
#         ████████  Discharge Pressure   68.4 psi<br>
#         █████▒▒▒  Suction Level        12.1 ft<br>
#         ████████  Motor Current       842 A<br><br>
#         <span style="color:#0f0;">● All systems normal</span>
#     </div>
